# %%
import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup

# %%
def get_web_page(url):
    resp = requests.get(url)
    resp.encoding = 'utf-8'
    
    if resp.status_code != 200:
        print('Invalid url:', resp.url)
        return None
    else:
        return resp.text

# %%
if __name__ == "__main__":
    url='https://www.vgchartz.com/games/games.php?page&results=50&name=&console=&keyword=&publisher=&genre=&order=CriticScore&ownership=Both&boxart=Both&banner=Both&showdeleted=&region=All&goty_year=&developer=&direction=DESC&showtotalsales=0&shownasales=0&showpalsales=0&showjapansales=0&showothersales=0&showpublisher=1&showdeveloper=0&showreleasedate=1&showlastupdate=1&showvgchartzscore=1&showcriticscore=1&showuserscore=1&showshipped=1&alphasort=&showmultiplat=No.html'
    rate_df = pd.read_html(url)[7] # 7 refers to the table index of this page
    
        
        
        outputpath='遊戲評分.xlsx'
        rate_df.to_excel(outputpath,index=False,header=False)
        pd.read_excel('遊戲評分.xlsx')
        print(rate_df)
# Out:
#    VGChartz_Score Critic_Score User_Score
# 0             N/A         10.0        N/A
# 1             N/A         10.0        N/A
# 2             N/A         10.0        N/A
# 3             N/A         10.0        N/A
# 4             N/A         10.0        N/A
# 5             N/A         10.0        N/A
# 6             N/A         10.0        N/A
# 7             N/A         10.0        N/A
# 8             N/A         10.0        8.2
# 9             N/A         10.0        N/A
# 10            N/A         10.0        N/A
# 11            N/A         10.0       10.0
# 12            N/A         10.0        N/A
# 13            N/A         10.0       10.0
# 14            9.0         10.0        9.0
# 15            9.0         10.0        N/A
# 16            N/A          9.9       10.0
# 17            N/A          9.8        N/A
# 18            8.0          9.8        N/A
# 19            N/A          9.8        N/A
# 20            N/A          9.7        N/A
# 21            N/A          9.7        N/A
# 22            N/A          9.7        N/A
# 23            N/A          9.7        N/A
# 24            N/A          9.7        N/A
# 25            9.0          9.7       10.0
# 26            N/A          9.7        N/A
# 27            N/A          9.7        N/A
# 28            N/A          9.7        9.5
# 29            9.6          9.7        9.8
# 30            N/A          9.7        N/A
# 31            N/A          9.7        N/A
# 32            9.6          9.7        9.6
# 33            N/A          9.7        N/A
# 34            N/A          9.7        N/A
# 35            N/A          9.6        N/A
# 36            N/A          9.6        N/A
# 37            8.8          9.6        9.5
# 38            N/A          9.6        9.3
# 39            N/A          9.6        N/A
# 40            N/A          9.6        N/A
# 41            N/A          9.6        N/A
# 42            9.3          9.6        9.5
# 43            N/A          9.6        N/A
# 44            N/A          9.6        N/A
# 45            N/A          9.6        N/A
# 46            N/A          9.6        N/A
# 47            N/A          9.6        N/A
# 48            N/A          9.6        N/A
# 49            N/A          9.6        N/A
#    VGChartz_Score Critic_Score User_Score
# 0             N/A          9.6        N/A
# 1             N/A          9.6        N/A
# 2             N/A          9.6        N/A
# 3             9.3          9.6        9.5
# 4             N/A          9.6        N/A
# 5             N/A          9.6        N/A
# 6             N/A          9.6        N/A
# 7             N/A          9.6        9.0
# 8             9.5          9.6        N/A
# 9             N/A          9.6        9.5
# 10            N/A          9.6        N/A
# 11            9.1          9.5        N/A
# 12            N/A          9.5        N/A
# 13            9.5          9.5        8.9
# 14            9.0          9.5        9.0
# 15            N/A          9.5        N/A
# 16            9.1          9.5       10.0
# 17            N/A          9.5        N/A
# 18            N/A          9.5        N/A
# 19            N/A          9.5        N/A
# 20            9.2          9.5        9.6
# 21            9.3          9.5        9.6
# 22            9.0          9.5        N/A
# 23            N/A          9.5        N/A
# 24            N/A          9.5        N/A
# 25            N/A          9.5        N/A
# 26            N/A          9.5        N/A
# 27            N/A          9.5        N/A
# 28            N/A          9.5        N/A
# 29            N/A          9.5        N/A
# 30            N/A          9.5        N/A
# 31            N/A          9.5        N/A
# 32            N/A          9.5        N/A
# 33            N/A          9.5        N/A
# 34            N/A          9.5        N/A
# 35            N/A          9.5        N/A
# 36            N/A          9.5        N/A
# 37            N/A          9.5        9.5
# 38            N/A          9.5        N/A
# 39            N/A          9.5        N/A
# 40            N/A          9.5        N/A
# 41            N/A          9.5        N/A
# 42            N/A          9.5        N/A
# 43            N/A          9.5        N/A
# 44            N/A          9.5        7.0
# 45            N/A          9.5        N/A
# 46            N/A          9.5        N/A
# 47            N/A          9.5        N/A
# 48            N/A          9.5        N/A
# 49            N/A          9.5        N/A

# %%
 rate_df
# Out:
#    VGChartz_Score Critic_Score User_Score
# 0             8.7          9.3        N/A
# 1             9.0          9.3        N/A
# 2             N/A          9.3        N/A
# 3             N/A          9.3        N/A
# 4             N/A          9.3        N/A
# 5             N/A          9.3        N/A
# 6             N/A          9.3        6.3
# 7             N/A          9.3        N/A
# 8             N/A          9.3        N/A
# 9             N/A          9.3        N/A
# 10            N/A          9.3        N/A
# 11            N/A          9.3        9.0
# 12            N/A          9.3        N/A
# 13            N/A          9.3        N/A
# 14            N/A          9.3        N/A
# 15            N/A          9.3        N/A
# 16            N/A          9.3        N/A
# 17            8.9          9.3        N/A
# 18            N/A          9.3        N/A
# 19            N/A          9.3        N/A
# 20            N/A          9.3        N/A
# 21            N/A          9.3        N/A
# 22            N/A          9.3        N/A
# 23            N/A          9.3        N/A
# 24            N/A          9.3        N/A
# 25            N/A          9.3        N/A
# 26            N/A          9.3        N/A
# 27            9.0          9.3        N/A
# 28            N/A          9.3        N/A
# 29            N/A          9.3        9.8
# 30            N/A          9.3        N/A
# 31            N/A          9.3        9.1
# 32            N/A          9.3        N/A
# 33            N/A          9.3        N/A
# 34            N/A          9.3        N/A
# 35            N/A          9.3        N/A
# 36            9.1          9.3        9.0
# 37            N/A          9.3        N/A
# 38            N/A          9.3        9.4
# 39            N/A          9.3        N/A
# 40            N/A          9.3        N/A
# 41            9.5          9.3        9.8
# 42            N/A          9.3        N/A
# 43            N/A          9.3        9.3
# 44            9.3          9.3        9.6
# 45            N/A          9.3        N/A
# 46            N/A          9.3        N/A
# 47            N/A          9.3        N/A
# 48            N/A          9.3        N/A
# 49            N/A          9.3        N/A

# %%
outputpath='遊戲評分.xlsx'
rate_df.to_excel(outputpath,index=False,header=False)

# %%
pd.read_excel('遊戲評分.xlsx')
# Out:
#     8.7  9.3  N/A
# 0   9.0  9.3  NaN
# 1   NaN  9.3  NaN
# 2   NaN  9.3  NaN
# 3   NaN  9.3  NaN
# 4   NaN  9.3  NaN
# 5   NaN  9.3  6.3
# 6   NaN  9.3  NaN
# 7   NaN  9.3  NaN
# 8   NaN  9.3  NaN
# 9   NaN  9.3  NaN
# 10  NaN  9.3  9.0
# 11  NaN  9.3  NaN
# 12  NaN  9.3  NaN
# 13  NaN  9.3  NaN
# 14  NaN  9.3  NaN
# 15  NaN  9.3  NaN
# 16  8.9  9.3  NaN
# 17  NaN  9.3  NaN
# 18  NaN  9.3  NaN
# 19  NaN  9.3  NaN
# 20  NaN  9.3  NaN
# 21  NaN  9.3  NaN
# 22  NaN  9.3  NaN
# 23  NaN  9.3  NaN
# 24  NaN  9.3  NaN
# 25  NaN  9.3  NaN
# 26  9.0  9.3  NaN
# 27  NaN  9.3  NaN
# 28  NaN  9.3  9.8
# 29  NaN  9.3  NaN
# 30  NaN  9.3  9.1
# 31  NaN  9.3  NaN
# 32  NaN  9.3  NaN
# 33  NaN  9.3  NaN
# 34  NaN  9.3  NaN
# 35  9.1  9.3  9.0
# 36  NaN  9.3  NaN
# 37  NaN  9.3  9.4
# 38  NaN  9.3  NaN
# 39  NaN  9.3  NaN
# 40  9.5  9.3  9.8
# 41  NaN  9.3  NaN
# 42  NaN  9.3  9.3
# 43  9.3  9.3  9.6
# 44  NaN  9.3  NaN
# 45  NaN  9.3  NaN
# 46  NaN  9.3  NaN
# 47  NaN  9.3  NaN
# 48  NaN  9.3  NaN

# %%
row = data.find_all('td', align='center')

# %%
 row
# Out:
# [<td align="center">
#  <img alt="XB" src="/images/consoles/XB_b.png"/>
#  </td>,
#  <td align="center">N/A  </td>,
#  <td align="center">9.5  </td>,
#  <td align="center">N/A  </td>,
#  <td align="center">N/A</td>,
#  <td align="center" width="75">20th Sep 05  </td>,
#  <td align="center" width="75">N/A</td>]

# %%
<td style="font-size:12pt;">    <a href="https://www.vgchartz.com/game/3312/final-fantasy-ii/?region=All">Final Fantasy II    </a>  </td>

# %%
title = data.find_all('td',style="font-size:12pt;")

# %%
title
# Out:
# [<td style="font-size:12pt;"> <a href="https://www.vgchartz.com/game/1655/ninja-gaiden-black/?region=All">Ninja Gaiden Black    </a> </td>]

# %%
game_name = data.find('a').string

# %%
game_name
